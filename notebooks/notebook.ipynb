# %%
cd ..
# Out:
# /home/seanammirati/dev/mta_feeds

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd src/mta_feeds
# Out:
# /home/seanammirati/dev/mta_feeds/src/mta_feeds

# %%
from mta_feeds import *

# %%
conn = dbconnector()

# %%
import pandas as pd

# %%
df = pd.read_sql('SELECT s.*, a.*, t.train FROM actions a JOIN stops s ON a.stop = s.id JOIN trip t ON a.trip = t.id', conn)

# %%
df
# Out:
#          id  stop_number on_line stop_code                         stop_name  \
# 0      F33S           33       F      None                          Avenue N
# 1      F33S           33       F      None                          Avenue N
# 2      N07S            7       N      None                          Bay Pkwy
# 3      N07S            7       N      None                          Bay Pkwy
# 4      R33S           33       R      None                              9 St
# ...     ...          ...     ...       ...                               ...
# 12819  701S            1       7      None                Flushing - Main St
# 12820  M23N           23       M      None                          Broad St
# 12821  M23N           23       M      None                          Broad St
# 12822  M01N            1       M      None  Middle Village - Metropolitan Av
# 12823  M01N            1       M      None  Middle Village - Metropolitan Av
#
#         stop_lat   stop_lon zone_id stop_url  location_type parent_station  \
# 0      40.615140 -73.974200    None     None            0.0            F33
# 1      40.615140 -73.974200    None     None            0.0            F33
# 2      40.611816 -73.981850    None     None            0.0            N07
# 3      40.611816 -73.981850    None     None            0.0            N07
# 4      40.670850 -73.988304    None     None            0.0            R33
# ...          ...        ...     ...      ...            ...            ...
# 12819  40.759600 -73.830030    None     None            0.0            701
# 12820  40.706474 -74.011055    None     None            0.0            M23
# 12821  40.706474 -74.011055    None     None            0.0            M23
# 12822  40.711395 -73.889600    None     None            0.0            M01
# 12823  40.711395 -73.889600    None     None            0.0            M01
#
#            id  trip  stop       type                             time train
# 0      215956     0  F33S    arrival        2019-10-14 00:41:35+00:00     F
# 1      215957     0  F33S  departure 2019-10-14 00:41:36.022854+00:00     F
# 2      215958     1  N07S    arrival        2019-10-14 00:41:35+00:00     D
# 3      215959     1  N07S  departure 2019-10-14 00:41:36.016300+00:00     D
# 4      215960     2  R33S    arrival        2019-10-14 00:41:25+00:00     R
# ...       ...   ...   ...        ...                              ...   ...
# 12819  228775   474  701S  departure 2019-10-14 01:30:51.613933+00:00     7
# 12820  228776   475  M23N    arrival        2019-10-14 01:31:00+00:00     J
# 12821  228777   475  M23N  departure 2019-10-14 01:31:00.449943+00:00     J
# 12822  228778   476  M01N    arrival        2019-10-14 01:31:00+00:00     M
# 12823  228779   476  M01N  departure 2019-10-14 01:31:00.416486+00:00     M
#
# [12824 rows x 17 columns]

# %%
df.sort_values(by='trip')
# Out:
#          id  stop_number on_line stop_code                         stop_name  \
# 0      F33S           33       F      None                          Avenue N
# 2864   D42S           42       D      None              W 8 St - NY Aquarium
# 2726   D42S           42       D      None              W 8 St - NY Aquarium
# 2725   D42S           42       D      None              W 8 St - NY Aquarium
# 2580   D42S           42       D      None              W 8 St - NY Aquarium
# ...     ...          ...     ...       ...                               ...
# 12819  701S            1       7      None                Flushing - Main St
# 12820  M23N           23       M      None                          Broad St
# 12821  M23N           23       M      None                          Broad St
# 12822  M01N            1       M      None  Middle Village - Metropolitan Av
# 12823  M01N            1       M      None  Middle Village - Metropolitan Av
#
#         stop_lat   stop_lon zone_id stop_url  location_type parent_station  \
# 0      40.615140 -73.974200    None     None            0.0            F33
# 2864   40.576126 -73.975940    None     None            0.0            D42
# 2726   40.576126 -73.975940    None     None            0.0            D42
# 2725   40.576126 -73.975940    None     None            0.0            D42
# 2580   40.576126 -73.975940    None     None            0.0            D42
# ...          ...        ...     ...      ...            ...            ...
# 12819  40.759600 -73.830030    None     None            0.0            701
# 12820  40.706474 -74.011055    None     None            0.0            M23
# 12821  40.706474 -74.011055    None     None            0.0            M23
# 12822  40.711395 -73.889600    None     None            0.0            M01
# 12823  40.711395 -73.889600    None     None            0.0            M01
#
#            id  trip  stop       type                             time train
# 0      215956     0  F33S    arrival        2019-10-14 00:41:35+00:00     F
# 2864   218820     0  D42S    arrival        2019-10-14 00:51:55+00:00     F
# 2726   218682     0  D42S  departure 2019-10-14 00:51:35.421032+00:00     F
# 2725   218681     0  D42S    arrival        2019-10-14 00:51:35+00:00     F
# 2580   218536     0  D42S  departure 2019-10-14 00:50:56.548499+00:00     F
# ...       ...   ...   ...        ...                              ...   ...
# 12819  228775   474  701S  departure 2019-10-14 01:30:51.613933+00:00     7
# 12820  228776   475  M23N    arrival        2019-10-14 01:31:00+00:00     J
# 12821  228777   475  M23N  departure 2019-10-14 01:31:00.449943+00:00     J
# 12822  228778   476  M01N    arrival        2019-10-14 01:31:00+00:00     M
# 12823  228779   476  M01N  departure 2019-10-14 01:31:00.416486+00:00     M
#
# [12824 rows x 17 columns]

# %%
df['latest_time'] = df.groupby(['trip', 'stop'])['time'].transform('max')

# %%
df['first_time'] = df.groupby(['trip', 'stop'])['time'].transform('min')

# %%
test = df.drop_duplicates(['trip', 'stop']).sort_values(by=['trip', 'latest_time']).groupby('trip')[['latest_time', 'stop_lat', 'stop_lon']].diff()

# %%
test['distance'] = ((test['stop_lat'] ** 2) + (test['stop_lon'] ** 2)) ** .5

# %%
test['raw_met'] = test['latest_time'].dt.total_seconds() / test['distance']

# %%
test['stand_met'] = (test['raw_met'] - test['raw_met'].mean()) / test['raw_met'].std()

# %%
import numpy as np

# %%
test.loc[test['raw_met'] == np.inf, 'raw_met'] = 0

# %%
test

# %%
pd.options.display.max_rows = 1000

# %%
df.drop_duplicates(['trip', 'stop'])[df['trip'] == 94].sort_values(by='latest_time')
# Out:
# /home/seanammirati/anaconda3/envs/mta_feeds/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         id  stop_number on_line stop_code                  stop_name  \
# 188   L28N           28       L      None                   E 105 St
# 661   L27N           27       L      None                New Lots Av
# 927   L26N           26       L      None                 Livonia Av
# 1341  L25N           25       L      None                  Sutter Av
# 1699  L24N           24       L      None                Atlantic Av
# 2189  L22N           22       L      None               Broadway Jct
# 2423  L21N           21       L      None  Bushwick Av - Aberdeen St
# 2821  L20N           20       L      None                  Wilson Av
# 3230  L19N           19       L      None                  Halsey St
# 3583  L17N           17       L      None       Myrtle - Wyckoff Avs
# 6826  222782    94  L10N  arrival 2019-10-14 01:08:09+00:00     L
# 7344  223300    94  L08N  arrival 2019-10-14 01:09:32+00:00     L
# 8284  224240    94  L06N  arrival 2019-10-14 01:13:22+00:00     L
# 8555  224511    94  L05N  arrival 2019-10-14 01:14:09+00:00     L
# 9075  225031    94  L03N  arrival 2019-10-14 01:17:15+00:00     L
# 9489  225445    94  L02N  arrival 2019-10-14 01:17:22+00:00     L
#
#                           latest_time
# 188  2019-10-14 00:42:15.452118+00:00
# 661  2019-10-14 00:44:06.567197+00:00
# 927  2019-10-14 00:45:16.451047+00:00
# 1341 2019-10-14 00:46:36.691935+00:00
# 1699 2019-10-14 00:47:54.967712+00:00
# 2189        2019-10-14 00:51:30+00:00
# 2423 2019-10-14 00:51:53.139413+00:00
# 2821 2019-10-14 00:52:35.032100+00:00
# 3230 2019-10-14 00:54:27.733974+00:00
# 3583        2019-10-14 00:56:54+00:00
# 3995 2019-10-14 00:57:51.512276+00:00
# 4280 2019-10-14 00:58:50.583737+00:00
# 5023 2019-10-14 01:00:15.287789+00:00
# 5423 2019-10-14 01:01:25.691741+00:00
# 5698 2019-10-14 01:02:36.558457+00:00
# 6076 2019-10-14 01:04:17.449241+00:00
# 6826 2019-10-14 01:08:09.710113+00:00
# 7344 2019-10-14 01:09:33.446595+00:00
# 8284 2019-10-14 01:13:23.269740+00:00
# 8555 2019-10-14 01:14:10.531625+00:00
# 9075 2019-10-14 01:17:15.538803+00:00
# 9489 2019-10-14 01:17:22.950516+00:00

# %%
df['est_error'] = df['latest_time'] - df['time']

# %%
df['est_error_min'] = df['est_error'].dt.total_seconds()/60

# %%
droped_dupes = df.sort_values(by=['trip', 'time']).drop_duplicates(['trip', 'stop'])

# %%
droped_dupes.loc[droped_dupes['est_error_min'] > 1, 'est_error_min'].hist(bins=50)

# %%
droped_dupes['error_f_l'] = droped_d
# Out:
#          id  stop_number on_line stop_code                         stop_name  \
# 0      F33S           33       F      None                          Avenue N
# 314    F34S           34       F      None                          Avenue P
# 677    F35S           35       F      None                         Kings Hwy
# 1238   F36S           36       F      None                          Avenue U
# 1597   F38S           38       F      None                          Avenue X
# ...     ...          ...     ...       ...                               ...
# 12815  F27N           27       F      None                         Church Av
# 12816  H15N           15       H      None      Rockaway Park - Beach 116 St
# 12818  701S            1       7      None                Flushing - Main St
# 12820  M23N           23       M      None                          Broad St
# 12822  M01N            1       M      None  Middle Village - Metropolitan Av
#
#         stop_lat   stop_lon zone_id stop_url  location_type  ...      id  \
# 0      40.615140 -73.974200    None     None            0.0  ...  215956
# 314    40.608944 -73.973020    None     None            0.0  ...  216270
# 677    40.603218 -73.972360    None     None            0.0  ...  216633
# 1238   40.596060 -73.973360    None     None            0.0  ...  217194
# 1597   40.589620 -73.974250    None     None            0.0  ...  217553
# ...          ...        ...     ...      ...            ...  ...     ...
# 12815  40.644040 -73.979675    None     None            0.0  ...  228771
# 12816  40.580902 -73.835594    None     None            0.0  ...  228772
# 12818  40.759600 -73.830030    None     None            0.0  ...  228774
# 2705  00:07:33.820211 -0.002296 -0.007445  0.007791   58249.308244   4.572701
# 10188 00:03:26.651494  0.003510 -0.000140  0.003513   58828.293259   4.634750
# 10616 00:05:25.343597  0.005432 -0.000099  0.005433   59883.942738   4.747881
# 11775 00:04:35.121492  0.001490 -0.004326  0.004575   60130.457465   4.774299
# 2189  00:03:35.032288  0.003510 -0.000140  0.003513   61214.086836   4.890429
# 5417  00:05:24.822006  0.003853 -0.002340  0.004508   72056.086791   6.052339
# 8730  00:05:29.739474  0.003853 -0.002340  0.004508   73146.941149   6.169243
# 8333  00:10:36.408312 -0.004776 -0.005820  0.007529   84530.035963   7.389140
# 6931  00:21:20.140254 -0.013647 -0.006040  0.014924   85777.975407   7.522878
# 9389  00:01:45.761831  0.000630 -0.000099  0.000638  165840.783471  16.103005
# 7960  00:02:20.282675 -0.000630  0.000099  0.000638  219971.501150  21.904056
# 3734  00:02:44.905795  0.000630 -0.000099  0.000638  258582.004332  26.041845
# 2719  00:03:35.096675 -0.000630  0.000099  0.000638  337284.261882  34.476165

# %%
test['stand_met'].hist(bins = 50)

# %%
test['raw_met'].max()
# Out:
# 337284.26188174484

# %%
# %matplotlib inline

# %%
(df.drop_duplicates(subset=['trip', 'stop']).groupby(['trip', 'train']).apply(lambda x: x.sort_values(by=['latest_time'])['latest_time'].diff()).reset_index().groupby('train').apply(lambda x: (x['latest_time'].dt.total_seconds()/60).agg(['mean', 'std', 'max', 'min', 'median'] )))
# Out:
# /home/seanammirati/anaconda3/envs/mta_feeds/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1112: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# latest_time      mean       std        max       min    median
# train
# 1            1.673861  0.683670   4.889258  0.673037  1.484735
# 2            2.173217  3.081942  55.955561  0.683333  1.737364
# 3            2.186168  1.178372  11.197979  1.033619  1.746953
# 4            2.367229  1.155287   6.630964  1.017132  1.837710
# 5            2.875935  1.836253  11.648407  1.058469  2.608489
# 6            1.633232  0.438433   3.477601  0.991118  1.550312
# 7            1.800493  0.698574   5.750442  0.836999  1.583024
# A            2.656456  1.508824   8.334138  0.340663  2.083553
# C            1.759523  0.519798   5.495658  0.240720  1.665088
# D            2.522137  1.876097  14.248441  0.254598  1.919577
# E            2.601172  2.292635  21.335671  1.000836  1.910842
# F            2.247867  1.537388  11.081876  0.072106  1.919607
# FS           2.981595  3.155219  12.837371  1.492489  2.001670
# G            1.832455  0.501542   3.412059  0.615185  1.756251
# GS                NaN       NaN        NaN       NaN       NaN
# H            2.385110  1.293233   5.004491  0.664316  2.050371
# J            2.054601  1.280242   7.252401  0.172434  1.632060
# L            1.797553  1.215494   8.251200  0.043740  1.504162
# M            2.107489  1.252387   8.998409  0.254443  1.828948
# N            2.609796  1.858086  12.665213  0.336554  1.919609
# Q            2.123047  1.211917  10.163235  0.057542  1.838203
# R            2.219203  1.474517  11.336795  0.418432  1.755933
# SI           1.978511  0.654962   3.855860  0.336572  1.977034

# %%
(df.drop_duplicates(subset=['trip', 'stop']).groupby(['trip']).apply(lambda x: x.sort_values(by=['latest_time'])['latest_time'].diff()).reset_index()['latest_time'].dt.total_seconds()/60).mean()
# Out:
# 2.0996011539350374

# %%
(df.drop_duplicates(subset=['trip', 'stop']).groupby(['trip']).apply(lambda x: x.sort_values(by=['latest_time'])['latest_time'].diff()).reset_index()['latest_time'].dt.total_seconds()/60).std()
# Out:
# 1.5459107645541807

# %%
(df.drop_duplicates(subset=['trip', 'stop']).sort_values(by=['trip', 'stop', 'latest_time'])['latest_time'].diff().dt.total_seconds()/60).hist()

# %%
ls
# Out:
# __init__.py   mta_kafka.py    __pycache__/
# mta_feeds.py  mta_tracker.py  skeleton.py

# %%
cd ../..
# Out:
# /home/seanammirati/dev/mta_feeds

# %%
ls
# Out:
# AUTHORS.rst          Dockerfile   pull_data.sh*     setup.cfg
# CHANGELOG.rst        docs/        README.md         setup.py
# current_updates.csv  LICENSE.txt  README.rst        src/
# data/                notebooks/   requirements.txt  tests/

# %%
import pandas as pd

# %%
df = pd.read_csv('current_updates.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'stop_id', 'route_id', 'trip_id', 'direction',
#        'arrival_est', 'current_time', 'estimated_TTA', 'between_stops',
#        'time_at_station'],
#       dtype='object')

# %%
df['last_stop'] = df.groupby(['trip_id'])['stop_id'].transform('last')

# %%
df['arrival_est'] = pd.to_datetime(df['arrival_est']).dt.tz_convert('US/Eastern')

# %%
df['arrival_est']
# Out:
# 0       2019-10-13 15:02:46-04:00
# 1       2019-10-13 15:04:49-04:00
# 2       2019-10-13 15:04:00-04:00
# 3       2019-10-13 15:03:42-04:00
# 4       2019-10-13 15:04:59-04:00
#                    ...
# 12364   2019-10-13 16:06:30-04:00
# 12365   2019-10-13 16:10:30-04:00
# 12366   2019-10-13 16:11:30-04:00
# 12367   2019-10-13 16:15:30-04:00
# 12368   2019-10-13 16:16:30-04:00
# Name: arrival_est, Length: 12369, dtype: datetime64[ns, US/Eastern]

# %%
now
# Out:
# Timestamp('2019-10-13 15:46:43.830028-0400', tz='US/Eastern')

# %%
now = pd.to_datetime('now', utc=True).tz_convert('US/Eastern')
mask = (df['stop_id'] != df['last_stop']) | ((now - df['arrival_est']).dt.total_seconds() > 30 * 5)

# %%
subset = df[mask].groupby(['trip_id', 'stop_id']).last().reset_index()

# %%
def restructure_df(df):
    map_cols = {'trip_id':'trip',
                'stop_id': 'stop',
                'arrival_est':'arrival',
                'train': 'route_id',
                'depart': 'departure'}
    df.rename(columns=map_cols, inplace=True)

    df['departure'] = df['arrival'] + pd.to_timedelta(df['time_at_station'],        unit='s')
    
    other_cols = [col for col in df.columns if col not in map_cols.values()]
    df.drop(columns=other_cols, inplace=True)

    
    return df

# %%
restructure_df(subset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/mta_feeds/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_at_station'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-1699d2a4ad8d> in <module>
# ----> 1 restructure_df(subset)
#
# <ipython-input-107-6ada5c2f50bb> in restructure_df(df)
#      10     df.drop(columns=other_cols, inplace=True)
#      11
# ---> 12     df['departure'] = df['arrival'] + pd.to_timedelta(df['time_at_station'], unit='s')
#      13     return df
#
# ~/anaconda3/envs/mta_feeds/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/anaconda3/envs/mta_feeds/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_at_station'
